# %%
import pandas as pd
data=pd.read_excel("/home/simplon/Simplon/Python/Projet_p_e/chomage_zone.xls",1,skiprows=5)
data
# Out:
#                                                 ZE2010           LIBZE2010  \
# 0                                                 0050      Mont-de-Marsan
# 1                                                 0051             Alençon
# 2                                                 0052       Cosne-Clamecy
# 3                                                 0053               Mâcon
# 4                                                 0054    Nogent-le-Rotrou
# ..                                                 ...                 ...
# 300                                               9404              Bastia
# 301                                               9405  Calvi-L'Île-Rousse
# 302                                               9406               Corte
# 303                                               9407  Ghisonaccia-Aléria
# 304  Source : Insee, Estimations de taux de chômage...                 NaN
#
# ...

# %%
data.head(6)
# Out:
#   ZE2010                  LIBZE2010  REG         LIBREG  2003-T1  2003-T2  \
# 0   0050             Mont-de-Marsan  0.0  interrégional      6.0      6.1
# 1   0051                    Alençon  0.0  interrégional      7.2      7.5
# 2   0052              Cosne-Clamecy  0.0  interrégional      7.5      7.6
# 3   0053                      Mâcon  0.0  interrégional      5.3      5.3
# 4   0054           Nogent-le-Rotrou  0.0  interrégional      5.9      6.3
# 5   0055  Vallée de la Bresle-Vimeu  0.0  interrégional      7.6      7.6
#
#    2003-T3  2003-T4  2004-T1  2004-T2  ...  2017-T4  2018-T1  2018-T2  \
# 0      6.0      6.3      6.4      6.2  ...      7.3      7.4      7.1
# 1      7.2      7.6      7.7      7.4  ...      8.3      8.6      8.4
# 2      7.4      7.8      8.0      7.7  ...      8.1      8.3      8.1
# 3      5.2      5.3      5.4      5.4  ...      6.4      6.5      6.5
# 4      6.4      7.0      7.3      7.2  ...      8.1      8.3      8.1
# ...

# %%
print(data.columns.values)
# Out:
# ['ZE2010' 'LIBZE2010' 'REG' 'LIBREG' '2003-T1' '2003-T2' '2003-T3'
#  '2003-T4' '2004-T1' '2004-T2' '2004-T3' '2004-T4' '2005-T1' '2005-T2'
#  '2005-T3' '2005-T4' '2006-T1' '2006-T2' '2006-T3' '2006-T4' '2007-T1'
#  '2007-T2' '2007-T3' '2007-T4' '2008-T1' '2008-T2' '2008-T3' '2008-T4'
#  '2009-T1' '2009-T2' '2009-T3' '2009-T4' '2010-T1' '2010-T2' '2010-T3'
#  '2010-T4' '2011-T1' '2011-T2' '2011-T3' '2011-T4' '2012-T1' '2012-T2'
#  '2012-T3' '2012-T4' '2013-T1' '2013-T2' '2013-T3' '2013-T4' '2014-T1'
#  '2014-T2' '2014-T3' '2014-T4' '2015-T1' '2015-T2' '2015-T3' '2015-T4'
#  '2016-T1' '2016-T2' '2016-T3' '2016-T4' '2017-T1' '2017-T2' '2017-T3'
#  '2017-T4' '2018-T1' '2018-T2' '2018-T3' '2018-T4' '2019-T1' '2019-T2'
#  '2019-T3' '2019-T4' '2020-T1']

# %%
data['REG'].value_counts()
# Out:
# 84.0    35
# 75.0    31
# 44.0    31
# 76.0    30
# 32.0    26
# 27.0    23
# 28.0    20
# 52.0    19
# 24.0    19
# 11.0    19
# 53.0    18
# 93.0    17
# 0.0      9
# 94.0     7
# Name: REG, dtype: int64

# %%
data2=data.loc[data['REG'] == 93]
print (data2)
# Out:
#     ZE2010                 LIBZE2010   REG                      LIBREG  \
# 280   9301           Digne-les-Bains  93.0  Provence-Alpes-Côte d'Azur
# 281   9302                  Manosque  93.0  Provence-Alpes-Côte d'Azur
# 282   9303                  Briançon  93.0  Provence-Alpes-Côte d'Azur
# 283   9304                       Gap  93.0  Provence-Alpes-Côte d'Azur
# 284   9305            Cannes-Antibes  93.0  Provence-Alpes-Côte d'Azur
# 285   9306  Menton Vallée de la Roya  93.0  Provence-Alpes-Côte d'Azur
# 286   9307                      Nice  93.0  Provence-Alpes-Côte d'Azur
# 287   9308           Aix-en-Provence  93.0  Provence-Alpes-Côte d'Azur
# 288   9309                     Arles  93.0  Provence-Alpes-Côte d'Azur
# 289   9310         Marseille-Aubagne  93.0  Provence-Alpes-Côte d'Azur
# 290   9311          Istres-Martigues  93.0  Provence-Alpes-Côte d'Azur
# 291   9312         Salon-de-Provence  93.0  Provence-Alpes-Côte d'Azur
# ...

# %%
data2['ZE2010'].value_counts()
# Out:
# 9315    1
# 9308    1
# 9314    1
# 9317    1
# 9309    1
# 9301    1
# 9304    1
# 9305    1
# 9312    1
# 9303    1
# 9302    1
# 9313    1
# 9316    1
# 9307    1
# 9310    1
# 9311    1
# 9306    1
# Name: ZE2010, dtype: int64

# %%
T20 = data2['2020-T1']
data_t1_2020=pd.eval("T20 > 7.1")
print(data_t1_2020)
# Out:
# 280     True
# 281     True
# 282     True
# 283    False
# 284     True
# 285    False
# 286     True
# 287    False
# 288     True
# 289     True
# 290     True
# 291     True
# 292     True
# 293     True
# 294     True
# 295     True
# 296     True
# dtype: bool

# %%
T19 = data2['2019-T1']
data_t1_2019=pd.eval("T19 > 7.1")
print(data_t1_2019)
# Out:
# 280    True
# 281    True
# 282    True
# 283    True
# 284    True
# 285    True
# 286    True
# 287    True
# 288    True
# 289    True
# 290    True
# 291    True
# 292    True
# 293    True
# 294    True
# 295    True
# 296    True
# dtype: bool

# %%
T18 = data2['2018-T1']
data_t1_2018=pd.eval("T18 > 7.1")
print(data_t1_2018)
# Out:
# 280    True
# 281    True
# 282    True
# 283    True
# 284    True
# 285    True
# 286    True
# 287    True
# 288    True
# 289    True
# 290    True
# 291    True
# 292    True
# 293    True
# 294    True
# 295    True
# 296    True
# dtype: bool

# %%
data_7_1 = (data_t1_2020 & data_t1_2019 & data_t1_2018)
print (data_7_1)
# Out:
# 280     True
# 281     True
# 282     True
# 283    False
# 284     True
# 285    False
# 286     True
# 287    False
# 288     True
# 289     True
# 290     True
# 291     True
# 292     True
# 293     True
# 294     True
# 295     True
# 296     True
# dtype: bool

# %%
df = pd.DataFrame(data_7_1,columns=['booleen'])
print(df)
# Out:
#      booleen
# 280     True
# 281     True
# 282     True
# 283    False
# 284     True
# 285    False
# 286     True
# 287    False
# 288     True
# 289     True
# 290     True
# 291     True
# 292     True
# 293     True
# 294     True
# 295     True
# 296     True

# %%
df['booleen'].value_counts()
# Out:
# True     14
# False     3
# Name: booleen, dtype: int64

# %%
p_emploi=pd.read_excel("/home/simplon/Simplon/Python/Projet_p_e/pole_emploi.xlsx",0,skiprows=3)
p_emploi
# Out:
#     Code                     Libellé  Pôle emploi 2018
# 0      1                  Guadeloupe                17
# 1      2                  Martinique                11
# 2      3                      Guyane                 8
# 3      4                  La Réunion                17
# 4      6                     Mayotte                 3
# 5     11               Île-de-France               164
# 6     24         Centre-Val de Loire               116
# 7     27     Bourgogne-Franche-Comté               165
# 8     28                   Normandie               145
# 9     32             Hauts-de-France               171
# 10    44                   Grand Est               238
# 11    52            Pays de la Loire               104
# 12    53                    Bretagne                91
# 13    75          Nouvelle-Aquitaine               251
# 14    76                   Occitanie               262
# 15    84        Auvergne-Rhône-Alpes               294
# ...

# %%
bigdata = pd.merge(data,p_emploi,left_on = ['REG'], right_on = ['Code'])
print(bigdata)
# Out:
#     ZE2010           LIBZE2010   REG                LIBREG  2003-T1  2003-T2  \
# 0    0060*       Saint-Étienne  84.0  Auvergne-Rhône-Alpes      8.0      8.2
# 1     8201   Ambérieu-en-Bugey  84.0  Auvergne-Rhône-Alpes      5.7      5.8
# 2     8202     Bourg-en-Bresse  84.0  Auvergne-Rhône-Alpes      4.5      4.7
# 3     8203             Oyonnax  84.0  Auvergne-Rhône-Alpes      6.8      6.9
# 4     8204             Annonay  84.0  Auvergne-Rhône-Alpes      7.6      8.0
# ..     ...                 ...   ...                   ...      ...      ...
# 290   9403   Sartène-Propriano  94.0                 Corse     10.7     10.7
# 291   9404              Bastia  94.0                 Corse      9.2      8.9
# 292   9405  Calvi-L'Île-Rousse  94.0                 Corse     11.7     11.4
# 293   9406               Corte  94.0                 Corse      8.3      7.6
# 294   9407  Ghisonaccia-Aléria  94.0                 Corse      9.6      8.8
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
bigdata["quantile"]=pd.qcut(bigdata['Pôle emploi 2018'],4,labels=["q25","q50","q75","q100"])

# %%
bigdata
# Out:
#     ZE2010           LIBZE2010   REG                LIBREG  2003-T1  2003-T2  \
# 0    0060*       Saint-Étienne  84.0  Auvergne-Rhône-Alpes      8.0      8.2
# 1     8201   Ambérieu-en-Bugey  84.0  Auvergne-Rhône-Alpes      5.7      5.8
# 2     8202     Bourg-en-Bresse  84.0  Auvergne-Rhône-Alpes      4.5      4.7
# 3     8203             Oyonnax  84.0  Auvergne-Rhône-Alpes      6.8      6.9
# 4     8204             Annonay  84.0  Auvergne-Rhône-Alpes      7.6      8.0
# ..     ...                 ...   ...                   ...      ...      ...
# 290   9403   Sartène-Propriano  94.0                 Corse     10.7     10.7
# 291   9404              Bastia  94.0                 Corse      9.2      8.9
# 292   9405  Calvi-L'Île-Rousse  94.0                 Corse     11.7     11.4
# 293   9406               Corte  94.0                 Corse      8.3      7.6
# 294   9407  Ghisonaccia-Aléria  94.0                 Corse      9.6      8.8
#
# ...

# %%
bigdata.pivot_table(values=["2020-T1"], index=["LIBREG"],columns=['quantile'], aggfunc=np.mean)
# Out:
#                              2020-T1
# quantile                         q25       q50       q75      q100
# LIBREG
# Auvergne-Rhône-Alpes             NaN       NaN       NaN  6.728571
# Bourgogne-Franche-Comté          NaN  6.565217       NaN       NaN
# Bretagne                    6.661111       NaN       NaN       NaN
# Centre-Val-de-Loire         7.684211       NaN       NaN       NaN
# Corse                       8.514286       NaN       NaN       NaN
# Grand-Est                        NaN       NaN  7.264516       NaN
# Hauts-de-France                  NaN  9.911538       NaN       NaN
# Ile-de-France                    NaN  6.794737       NaN       NaN
# Normandie                   7.150000       NaN       NaN       NaN
# Nouvelle-Aquitaine               NaN       NaN  7.293548       NaN
# Occitanie                        NaN       NaN       NaN  9.603333
# Pays de la Loire            6.563158       NaN       NaN       NaN
# ...

# %%
import matplotlib.pyplot as plt

# %%
data_grp= data[['LIBREG','2003-T1','2003-T2', '2003-T3',
 '2003-T4', '2004-T1', '2004-T2', '2004-T3', '2004-T4','2005-T1', '2005-T2',
 '2005-T3' ,'2005-T4' ,'2006-T1', '2006-T2', '2006-T3', '2006-T4', '2007-T1',
 '2007-T2' ,'2007-T3', '2007-T4', '2008-T1', '2008-T2', '2008-T3', '2008-T4',
 '2009-T1' ,'2009-T2', '2009-T3', '2009-T4', '2010-T1' ,'2010-T2', '2010-T3',
 '2010-T4' ,'2011-T1', '2011-T2', '2011-T3', '2011-T4', '2012-T1', '2012-T2',
 '2012-T3' ,'2012-T4', '2013-T1', '2013-T2', '2013-T3', '2013-T4', '2014-T1',
 '2014-T2' ,'2014-T3', '2014-T4', '2015-T1', '2015-T2', '2015-T3', '2015-T4',
 '2016-T1' ,'2016-T2', '2016-T3', '2016-T4', '2017-T1', '2017-T2', '2017-T3',
 '2017-T4' ,'2018-T1', '2018-T2', '2018-T3', '2018-T4', '2019-T1', '2019-T2',
 '2019-T3' ,'2019-T4', '2020-T1']]
data.groupby("LIBREG")

# %%
dataok=data_grp.groupby("LIBREG",as_index=False).mean()

# %%
dataok['2020-T1'].plot(x='LIBREG',y='2020-T1',kind='bar',figsize=(15,6),title='Mon_diagramme',grid=True)

# %%
data_2 = pd.read_excel("/home/simplon/Simplon/Python/Projet_p_e/chomage_zone.xls",1,skiprows=5,usecols=range(3,73))
print(data_2)
# Out:
#             LIBREG  2003-T1  2003-T2  2003-T3  2003-T4  2004-T1  2004-T2  \
# 0    interrégional      6.0      6.1      6.0      6.3      6.4      6.2
# 1    interrégional      7.2      7.5      7.2      7.6      7.7      7.4
# 2    interrégional      7.5      7.6      7.4      7.8      8.0      7.7
# 3    interrégional      5.3      5.3      5.2      5.3      5.4      5.4
# 4    interrégional      5.9      6.3      6.4      7.0      7.3      7.2
# ..             ...      ...      ...      ...      ...      ...      ...
# 300          Corse      9.2      8.9      8.9      9.3      9.4      9.3
# 301          Corse     11.7     11.4     11.2     11.4     11.2     11.5
# 302          Corse      8.3      7.6      8.2      8.1      8.0      8.0
# 303          Corse      9.6      8.8      9.0      9.4      9.6      9.7
# 304            NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      2004-T3  2004-T4  2005-T1  ...  2017-T4  2018-T1  2018-T2  2018-T3  \
# ...

# %%
data_grp2= data_2[['LIBREG','2003-T1','2003-T2', '2003-T3',
 '2003-T4', '2004-T1', '2004-T2', '2004-T3', '2004-T4','2005-T1', '2005-T2',
 '2005-T3' ,'2005-T4' ,'2006-T1', '2006-T2', '2006-T3', '2006-T4', '2007-T1',
 '2007-T2' ,'2007-T3', '2007-T4', '2008-T1', '2008-T2', '2008-T3', '2008-T4',
 '2009-T1' ,'2009-T2', '2009-T3', '2009-T4', '2010-T1' ,'2010-T2', '2010-T3',
 '2010-T4' ,'2011-T1', '2011-T2', '2011-T3', '2011-T4', '2012-T1', '2012-T2',
 '2012-T3' ,'2012-T4', '2013-T1', '2013-T2', '2013-T3', '2013-T4', '2014-T1',
 '2014-T2' ,'2014-T3', '2014-T4', '2015-T1', '2015-T2', '2015-T3', '2015-T4',
 '2016-T1' ,'2016-T2', '2016-T3', '2016-T4', '2017-T1', '2017-T2', '2017-T3',
 '2017-T4' ,'2018-T1', '2018-T2', '2018-T3', '2018-T4', '2019-T1', '2019-T2',
 '2019-T3' ,'2019-T4', '2020-T1']]
data_2.groupby("LIBREG")

# %%
dataok_2=data_grp2.groupby("LIBREG").mean()
dataok_2
# Out:
#                              2003-T1    2003-T2   2003-T3    2003-T4  \
# LIBREG
# Auvergne-Rhône-Alpes        6.877143   7.022857  6.957143   7.188571
# Bourgogne-Franche-Comté     6.760870   6.926087  6.891304   7.317391
# Bretagne                    6.466667   6.627778  6.633333   6.866667
# Centre-Val-de-Loire         7.105263   7.357895  7.373684   7.773684
# Corse                       9.685714   9.342857  9.385714   9.500000
# Grand-Est                   7.103226   7.306452  7.264516   7.654839
# Hauts-de-France             9.930769  10.084615  9.880769  10.330769
# Ile-de-France               6.636842   6.963158  6.926316   7.231579
# Normandie                   7.705000   7.860000  7.735000   8.085000
# Nouvelle-Aquitaine          7.487097   7.664516  7.600000   7.900000
# Occitanie                   9.353333   9.360000  9.226667   9.583333
# Pays de la Loire            6.194737   6.331579  6.278947   6.605263
# ...

# %%
T_data = dataok_2.transpose().reset_index()
T_data
# Out:
# LIBREG    index  Auvergne-Rhône-Alpes  Bourgogne-Franche-Comté  Bretagne  \
# 0       2003-T1              6.877143                 6.760870  6.466667
# 1       2003-T2              7.022857                 6.926087  6.627778
# 2       2003-T3              6.957143                 6.891304  6.633333
# 3       2003-T4              7.188571                 7.317391  6.866667
# 4       2004-T1              7.340000                 7.408696  6.983333
# ..          ...                   ...                      ...       ...
# 64      2019-T1              7.428571                 7.339130  7.394444
# 65      2019-T2              7.214286                 7.208696  7.172222
# 66      2019-T3              7.240000                 7.239130  7.194444
# 67      2019-T4              6.962857                 6.908696  6.883333
# 68      2020-T1              6.728571                 6.565217  6.661111
#
# LIBREG  Centre-Val-de-Loire     Corse  Grand-Est  Hauts-de-France  \
# ...

# %%
T_data.rename(columns = {'index':'periode'},inplace=True)
T_data
# Out:
# LIBREG  periode  Auvergne-Rhône-Alpes  Bourgogne-Franche-Comté  Bretagne  \
# 0       2003-T1              6.877143                 6.760870  6.466667
# 1       2003-T2              7.022857                 6.926087  6.627778
# 2       2003-T3              6.957143                 6.891304  6.633333
# 3       2003-T4              7.188571                 7.317391  6.866667
# 4       2004-T1              7.340000                 7.408696  6.983333
# ..          ...                   ...                      ...       ...
# 64      2019-T1              7.428571                 7.339130  7.394444
# 65      2019-T2              7.214286                 7.208696  7.172222
# 66      2019-T3              7.240000                 7.239130  7.194444
# 67      2019-T4              6.962857                 6.908696  6.883333
# 68      2020-T1              6.728571                 6.565217  6.661111
#
# LIBREG  Centre-Val-de-Loire     Corse  Grand-Est  Hauts-de-France  \
# ...

# %%
print(data_2)
# Out:
#             LIBREG  2003-T1  2003-T2  2003-T3  2003-T4  2004-T1  2004-T2  \
# 0    interrégional      6.0      6.1      6.0      6.3      6.4      6.2
# 1    interrégional      7.2      7.5      7.2      7.6      7.7      7.4
# 2    interrégional      7.5      7.6      7.4      7.8      8.0      7.7
# 3    interrégional      5.3      5.3      5.2      5.3      5.4      5.4
# 4    interrégional      5.9      6.3      6.4      7.0      7.3      7.2
# ..             ...      ...      ...      ...      ...      ...      ...
# 300          Corse      9.2      8.9      8.9      9.3      9.4      9.3
# 301          Corse     11.7     11.4     11.2     11.4     11.2     11.5
# 302          Corse      8.3      7.6      8.2      8.1      8.0      8.0
# 303          Corse      9.6      8.8      9.0      9.4      9.6      9.7
# 304            NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#      2004-T3  2004-T4  2005-T1  ...  2017-T4  2018-T1  2018-T2  2018-T3  \
# ...

# %%
T_data["Provence-Alpes-Côte d'Azur"].plot(x='periode',y="Provence-Alpes-Côte d'Azur",kind='line')

# %%
T_data["Provence-Alpes-Côte d'Azur"].plot(x='periode',kind='line')

# %%
T_data[["Provence-Alpes-Côte d'Azur","Ile-de-France","Occitanie","periode"]]
print(T_data[["Provence-Alpes-Côte d'Azur","Ile-de-France","Occitanie","periode"]])
# Out:
# LIBREG  Provence-Alpes-Côte d'Azur  Ile-de-France  Occitanie  periode
# 0                         9.400000       6.636842   9.353333  2003-T1
# 1                         9.488235       6.963158   9.360000  2003-T2
# 2                         9.241176       6.926316   9.226667  2003-T3
# 3                         9.464706       7.231579   9.583333  2003-T4
# 4                         9.535294       7.447368   9.710000  2004-T1
# ..                             ...            ...        ...      ...
# 64                       10.029412       7.357895  10.796667  2019-T1
# 65                        9.705882       7.152632  10.500000  2019-T2
# 66                        9.600000       7.242105  10.403333  2019-T3
# 67                        9.182353       6.947368   9.993333  2019-T4
# 68                        8.864706       6.794737   9.603333  2020-T1
#
# [69 rows x 4 columns]

# %%
T_data[["Provence-Alpes-Côte d'Azur","Ile-de-France","Occitanie","periode"]].plot(x='periode',kind='line')
